# %% [markdown]
# <img src="https://dev.skillup.online/asset-v1:SkillUp+SKOAI101+PLU_2021_1+type@asset+block@SKO.png" width="250" align="center">
#
# <h1 align="center"><font size="5"> Analyzing and Visualizing Heart Failure Prediction Data</font></h1>

# %% [markdown]
# ## Importing Libraries

# %%
# import libraries
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ## Reading Data Set

# %%
# Read the data set using read_csv function

df=pd.read_csv("E:\SKillUp\Module - AI foundations\PRojects\Heart Failure\Heart_Failure.xls")

# %% [markdown]
# ### Get glimpse of data

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  75.0        0                       582         0                    1
# 1  55.0        0                      7861         0                    0
# 2  65.0        0                       146         0                    0
# 3  50.0        1                       111         0                    0
# 4  65.0        1                       160         1                    0
#
#    platelets  serum_creatinine  serum_sodium  sex/Week  smoking  DEATH_EVENT
# 0  265000.00               1.9           130         1        0            1
# 1  263358.03               1.1           136         1        0            1
# 2  162000.00               1.3           129         1        1            1
# 3  210000.00               1.9           137         1        0            1
# 4  327000.00               2.7           116         0        0            1

# %%
df.shape
# Out:
# (299, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   high_blood_pressure       299 non-null    int64
#  5   platelets                 299 non-null    float64
#  6   serum_creatinine          299 non-null    float64
#  7   serum_sodium              299 non-null    int64
#  8   sex/Week                  299 non-null    int64
#  9   smoking                   299 non-null    int64
#  10  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 25.8 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# count           299.000000     299.000000         299.00000    299.000000
# mean              0.351171  263358.029264           1.39388    136.625418
# std               0.478136   97804.236869           1.03451      4.412477
# min               0.000000   25100.000000           0.50000    113.000000
# 25%               0.000000  212500.000000           0.90000    134.000000
# 50%               0.000000  262000.000000           1.10000    137.000000
# 75%               1.000000  303500.000000           1.40000    140.000000
# max               1.000000  850000.000000           9.40000    148.000000
#
#          sex/Week    smoking  DEATH_EVENT
# count  299.000000  299.00000    299.00000
# mean     0.648829    0.32107      0.32107
# std      0.478136    0.46767      0.46767
# min      0.000000    0.00000      0.00000
# 25%      0.000000    0.00000      0.00000
# 50%      1.000000    0.00000      0.00000
# 75%      1.000000    1.00000      1.00000
# max      1.000000    1.00000      1.00000

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex/Week                  0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  high_blood_pressure  platelets  \
# age                      -0.101012             0.093289  -0.052354
# anaemia                  -0.012729             0.038182  -0.043786
# creatinine_phosphokinase -0.009639            -0.070590   0.024463
# diabetes                  1.000000            -0.012732   0.092193
# high_blood_pressure      -0.012732             1.000000   0.049963
# platelets                 0.092193             0.049963   1.000000
# serum_creatinine         -0.046975            -0.004935  -0.041198
# serum_sodium             -0.089551             0.037109   0.062125
# sex/Week                 -0.157730            -0.104615  -0.125120
# smoking                  -0.147173            -0.055711   0.028234
# DEATH_EVENT              -0.001943             0.079351  -0.049139
#
#                           serum_creatinine  serum_sodium  sex/Week   smoking  \
# age                               0.159187     -0.045966  0.065430  0.018668
# anaemia                           0.052174      0.041882 -0.094769 -0.107290
# creatinine_phosphokinase         -0.016408      0.059550  0.079791  0.002421
# diabetes                         -0.046975     -0.089551 -0.157730 -0.147173
# high_blood_pressure              -0.004935      0.037109 -0.104615 -0.055711
# platelets                        -0.041198      0.062125 -0.125120  0.028234
# serum_creatinine                  1.000000     -0.189095  0.006970 -0.027414
# serum_sodium                     -0.189095      1.000000 -0.027566  0.004813
# sex/Week                          0.006970     -0.027566  1.000000  0.445892
# smoking                          -0.027414      0.004813  0.445892  1.000000
# DEATH_EVENT                       0.294278     -0.195204 -0.004316 -0.012623
#
#                           DEATH_EVENT
# age                          0.253729
# anaemia                      0.066270
# creatinine_phosphokinase     0.062728
# diabetes                    -0.001943
# high_blood_pressure          0.079351
# platelets                   -0.049139
# serum_creatinine             0.294278
# serum_sodium                -0.195204
# sex/Week                    -0.004316
# smoking                     -0.012623
# DEATH_EVENT                  1.000000

# %% [markdown]
# ### Q1. Create new dataframe <code>df_old</code> with <code>age>=60</code> and replace all the values in <code>age</code> column of <code>df_old</code> with <code>old age</code>

# %%
# Write your code here
df_old=df[df['age'] >=60]
pd.set_option('mode.chained_assignment', None)
df_old['age'] = 'old age'
df_old.head()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  old age        0                       582         0                    1
# 2  old age        0                       146         0                    0
# 4  old age        1                       160         1                    0
# 5  old age        1                        47         0                    1
# 6  old age        1                       246         0                    0
#
#    platelets  serum_creatinine  serum_sodium  sex/Week  smoking  DEATH_EVENT
# 0   265000.0               1.9           130         1        0            1
# 2   162000.0               1.3           129         1        1            1
# 4   327000.0               2.7           116         0        0            1
# 5   204000.0               2.1           132         1        1            1
# 6   127000.0               1.2           137         1        0            1

# %% [markdown]
# <details><summary>Click Here for the Hint</summary>
#
#
#
# ```
#     df_old=df[df['age'] >=60]
#     df_old['age']='old age'
#
#
#
# ```
#
#
#
# </details>

# %% [markdown]
# ### Q2. Create new dataframe <code>df_middle_age</code> with <code>age</code>< 60 and replace all the values in <code>age</code> column of <code>df_middle_age</code> with <code>middle age</code>

# %%
# Write your code here
df_middle_age=df[df['age'] <60]
pd.set_option('mode.chained_assignment', None)
df_middle_age['age'] = 'middle age'
df_middle_age.head()
# Out:
#            age  anaemia  creatinine_phosphokinase  diabetes  \
# 1   middle age        0                      7861         0
# 3   middle age        1                       111         0
# 12  middle age        1                       981         0
# 13  middle age        1                       168         0
# 14  middle age        1                        80         0
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex/Week  \
# 1                     0  263358.03               1.1           136         1
# 3                     0  210000.00               1.9           137         1
# 12                    0  136000.00               1.1           137         1
# 13                    1  276000.00               1.1           137         1
# 14                    1  427000.00               1.0           138         0
#
#     smoking  DEATH_EVENT
# 1         0            1
# 3         0            1
# 12        0            1
# 13        0            1
# 14        0            0

# %% [markdown]
# ### Q3. Concatenate <code>df_old</code> and <code>df_middle_age</code> and form a new dataframe as <code>df_new</code>

# %%
# Hint: use pd.concat()
df_new = pd.concat([df_old, df_middle_age])
df_new.head(-10)
# Out:
#             age  anaemia  creatinine_phosphokinase  diabetes  \
# 0       old age        0                       582         0
# 2       old age        0                       146         0
# 4       old age        1                       160         1
# 5       old age        1                        47         0
# 6       old age        1                       246         0
# ..          ...      ...                       ...       ...
# 271  middle age        0                       582         1
# 273  middle age        0                        64         0
# 275  middle age        0                       582         0
# 278  middle age        1                      1051         1
# 279  middle age        0                        84         1
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex/Week  \
# 0                      1   265000.0               1.9           130         1
# 2                      0   162000.0               1.3           129         1
# 4                      0   327000.0               2.7           116         0
# 5                      1   204000.0               2.1           132         1
# 6                      0   127000.0               1.2           137         1
# ..                   ...        ...               ...           ...       ...
# 271                    0   221000.0               0.9           134         0
# 273                    0   189000.0               0.7           140         1
# 275                    1   422000.0               0.8           137         0
# 278                    0   232000.0               0.7           136         0
# 279                    0   451000.0               1.3           136         0
#
#      smoking  DEATH_EVENT
# 0          0            1
# 2          1            1
# 4          0            1
# 5          1            1
# 6          0            1
# ..       ...          ...
# 271        0            0
# 273        0            0
# 275        0            0
# 278        0            0
# 279        0            0
#
# [289 rows x 11 columns]

# %% [markdown]
# ### Q4. Visualize <code>diabetes, platelets, DEATH_EVENT</code> for <code>middle age</code> and <code>old age</code> people

# %%
# Hint: sns.barplot(x='',y='',data=)
fig, axs = plt.subplots(1,3, figsize = (10,5))
diabetes = sns.barplot(x = df_new['age'], y = df_new['diabetes'], data = df_new, ax = axs[0])
platelets = sns.barplot(x = df_new['age'], y = df_new['platelets'], data = df_new, ax = axs[1])
death_event = sns.barplot(x = df_new['age'], y = df_old['DEATH_EVENT'], data = df_new, ax = axs[2])

plt.tight_layout()

# %% [markdown]
# ### Q5. groupby dataframe by <code>age</code> and calculate mean

# %%
# Write your code here
grouped = df_new.groupby('age')
df_new_mean = grouped.mean().reset_index()
df_new_mean.head()
# Out:
#           age   anaemia  creatinine_phosphokinase  diabetes  \
# 0  middle age  0.395349                686.782946  0.418605
# 1     old age  0.458824                502.205882  0.417647
#
#    high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# 0             0.310078  272627.428915          1.217132    136.875969
# 1             0.382353  256324.190706          1.528000    136.435294
#
#    sex/Week   smoking  DEATH_EVENT
# 0  0.643411  0.310078     0.240310
# 1  0.652941  0.329412     0.382353

# %% [markdown]
# <details><summary>Click Here for the Hint</summary>
#
#
#
# ```
#     df_avg=df_new.groupby(by='age').mean()
#     df_avg.reset_index(inplace=True)
#
#
#
# ```
#
#
#
# </details>

# %% [markdown]
# ### Q6. Visualize average <code>platelets</code> for <code>middle age</code> and <code>old age</code> people

# %%
# Write your code here
#Assinging average values
old_age_platelets_avg = df_old['platelets'].mean()

# %%
middle_age_platelets_avg = df_middle_age['platelets'].mean()

# %%
#PLotting Bar Chart 
labels = [ 'Old Age' , 'Middle Age' ]
average = [ old_age_platelets_avg, middle_age_platelets_avg ] 
x = np.arange(len(labels))
width = 0.5
plt.bar( x, average, width, color = ['#FF7F0E', '#1F77B4'], edgecolor = 'black')
plt.xticks(x, labels)
plt.ylabel(' Average Platelet Count ' )
plt.title( ' Average Platelet Count for Old and Middle Age People ' )

for i,avg in enumerate(average):
    plt.text(x[i], avg, str(avg), ha = 'center', va='bottom')
plt.show()

# %% [markdown]
# ## Assignment Notebook Submission
#
# Once you complete your notebook you will have to share it. Save all your work and download the file. You will be submitting your notebook for peer review in the next section of the course.

# %% [markdown]
# ## Author(s)
#
# Aditya Singh
#
# ## Changelog
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 1.0 | Aditya | Created new version |
# |   |   |   |   |
